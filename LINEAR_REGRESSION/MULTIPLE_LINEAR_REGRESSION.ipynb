# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
data =pd.read_csv("D:/MACHINE_LEARNING/PHASE2/LINEAR_REGRESSION/HousingData.csv")

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
X=data[['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT']]
Y=data['MEDV']

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90    NaN

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
X_train.head()
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 5     0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# 116   0.13158  0.0  10.01   0.0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142  0.0   6.91   0.0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393  0.0   8.14   0.0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570  0.0  18.10   0.0  0.580  5.926  71.0  2.9084   24  666
#
#      PTRATIO       B  LSTAT
# 5       18.7  394.12   5.21
# 116     17.8  393.30    NaN
# 45      17.9  396.90  10.21
# 16      21.0  386.85   6.58
# 468     20.2  368.74  18.13

# %%
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# %%
trf1=ColumnTransformer([
   ('num', num_pipeline, X.columns)
])

# %%
trf2=LinearRegression()

# %%
pipe=Pipeline([
    ("trf1",trf1),
    ("trf2",trf2)
])

# %%
pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('trf1',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object'))])),
#                 ('trf2', LinearRegression())])

# %%
Y_predict=pipe.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
print("Predictions:", Y_predict) 
print("R2 Score:", r2_score(Y_test, Y_predict)) 
print("MSE:", mean_squared_error(Y_test, Y_predict))
# Out:
# Predictions: [28.9374149  37.07304671 15.15824707 25.59079669 18.51249014 22.9224732
#  17.98048338 14.42684379 22.06118216 20.81179321 25.10710077 18.7280536
#  -6.31900083 21.85652534 19.0211192  25.51260116 19.37792708  5.95171499
#  40.85420827 17.17691806 25.03739352 30.36508097 11.38739503 22.87828871
#  17.50615507 15.11529181 21.50352281 14.47474002 23.13096798 19.55796172
#  22.17502166 25.2549366  25.38313785 17.34560951 16.23169931 17.26234025
#  30.90624604 20.38720519 24.66260953 22.95762537 14.50885487 31.79168268
#  42.81647959 17.98159357 27.35228492 16.55933678 13.94631048 26.52214645
#  19.74265463 30.25608467 21.0220061  33.47226081 15.9679993  26.26674791
#  39.5833181  22.49822654 18.74466842 33.03174115 25.24212083 13.17269654
#  22.8454891  31.01734562 31.54634839 16.75114519 21.21601556 17.09250986
#  19.98323684 26.38211499 31.29810985 11.72255579 20.95897005 26.62849983
#  10.95036792 13.41567239 23.9631736   5.6512702  21.44836761 41.56726393
#  18.16266676  9.47283362 21.40454163 12.82544709 21.86851727  9.16635292
#  22.77625936 32.50798662 19.09792034 25.75389337 29.03849061 19.79827565
#  25.98757803  5.5519289  19.67806538 15.57556157 12.07857309 20.28252796
#  23.71929333 -0.34116568 13.5731547  15.57294354 22.62418842 24.62366852
#  10.43171273 19.6988552  23.19797674 12.53154848 18.49514401 25.96266356
#  21.20234542 24.74726705  7.86784823 20.26043085 22.13515612 27.48449641
#  32.0188462  14.76491649 34.76582956 13.04400477 21.34033845 28.27614517
#  15.36632174 25.17641691  3.35163849 23.7164895  26.25522301 23.09869903
#  25.43130267 33.18048225 21.6399178  38.46604351 14.39884999 26.14426438
#  17.60117579 20.78200752 10.44811158 20.49713693 22.66230247 32.00151353
#  31.79426622 15.51782203 17.0134488  29.09340186 25.06843208 17.52003105
#   6.5266549  25.95095152 23.78803739 20.60279226 13.58499408 40.21341778
#  16.39100175 17.86344051]
# R2 Score: 0.7072372904062467
# MSE: 21.81465575866704

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
trf3=Ridge()

# %%
pipe=Pipeline([
    ("trf1",trf1),
    ("trf3",trf3)
])

# %%
param_grid = {
    'trf3__alpha': [0.01, 0.1, 1, 10, 50, 100]
}

# %%
Ridge=GridSearchCV(
    estimator=pipe,
    param_grid=param_grid,
    cv=10,
    scoring='neg_mean_squared_error')

# %%
Ridge.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('trf1',
#                                         Pipeline(steps=[('imputer',
#                                                          SimpleImputer()),
#                                                         ('scaler',
#                                                          StandardScaler())])),
#                                        ('trf3', Ridge())]),
#              param_grid={'trf3__alpha': [0.01, 0.1, 1, 10, 50, 100]},
#              scoring='neg_mean_squared_error')

# %%
Y_pred=Ridge.predict(X_test)

# %%
r2=r2_score(Y_test,Y_pred)
mse=mean_squared_error(Y_test,Y_pred)
mae=mean_absolute_error(Y_test,Y_pred)

# %%
print("r2_score is ",r2)
print("MSE is",mse)
print("MAE is",mae)
# Out:
# r2_score is  0.704027352323273
# MSE is 22.0538381818106
# MAE is 3.142673961783336

# %%
from

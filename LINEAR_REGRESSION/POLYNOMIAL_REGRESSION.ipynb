# %%
import pandas as pd

# %%
data=pd.read_csv("salary_dataset.csv")

# %%
data.head()
# Out:
#    YearsExperience  Salary
# 0              1.0   56054
# 1              1.0   50528
# 2              1.0   44579
# 3              1.0   48773
# 4              1.0   37610

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5652 entries, 0 to 5651
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  5652 non-null   float64
#  1   Salary           5652 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 88.4 KB

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
X=data[['YearsExperience']]

# %%
Y=data['Salary']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("poly", PolynomialFeatures(degree=3)),
    ("lr", LinearRegression())
])

# %%
pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('poly', PolynomialFeatures(degree=3)),
#                 ('lr', LinearRegression())])

# %%
Y_pred=pipe.predict(X_test)

# %%
r2=r2_score(Y_test,Y_pred)
MSE=mean_squared_error(Y_test,Y_pred)
MAE=mean_absolute_error(Y_test,Y_pred)

# %%
print("r2 score is",r2)
print("MSE is",MSE)
print("MAE is",MAE)
# Out:
# r2 score is 0.9456079501214762
# MSE is 25309589.533346344
# MAE is 3997.1220532239586

# %%
param_grid = {
    "poly__degree": [1, 2, 3, 4, 5, 6]
}

# %%
grid=GridSearchCV(
    estimator=pipe,
    param_grid=param_grid,
    cv=5,
    scoring='r2',
    verbose=1,
    n_jobs=-1
)

# %%
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('poly', PolynomialFeatures(degree=3)),
#                                        ('lr', LinearRegression())]),
#              n_jobs=-1, param_grid={'poly__degree': [1, 2, 3, 4, 5, 6]},
#              scoring='r2', verbose=1)

# %%
best_model=grid.best_estimator_
best_params=grid.best_params_
best_score=grid.best_score_

# %%
print(best_params)
print(best_score)
# Out:
# {'poly__degree': 1}
# 0.9443804461315457

# %%
Y_pred1=best_model.predict(X_test)

# %%
r2=r2_score(Y_test,Y_pred1)
MSE=mean_squared_error(Y_test,Y_pred1)
MAE=mean_absolute_error(Y_test,Y_pred1)

# %%
print("r2 score is",r2)
print("MSE is",MSE)
print("MAE is",MAE)
# Out:
# r2 score is 0.9457506573899297
# MSE is 25243185.29971205
# MAE is 3991.2701946436364
